# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
cap=pd.read_csv('capmetro_UT.csv')
cap
# Out:
#                 timestamp  boarding  alighting day_of_week  temperature  \
# 0     2018-09-01 06:00:00         0          1         Sat        74.82
# 1     2018-09-01 06:15:00         2          1         Sat        74.82
# 2     2018-09-01 06:30:00         3          4         Sat        74.82
# 3     2018-09-01 06:45:00         3          4         Sat        74.82
# 4     2018-09-01 07:00:00         2          4         Sat        74.39
# ...                   ...       ...        ...         ...          ...
# 5819  2018-11-30 20:45:00        43         29         Fri        70.73
# 5820  2018-11-30 21:00:00        24         19         Fri        69.88
# 5821  2018-11-30 21:15:00        33         16         Fri        69.88
# 5822  2018-11-30 21:30:00        25         15         Fri        69.88
# 5823  2018-11-30 21:45:00        21         13         Fri        69.88
#
#       hour_of_day month  weekend
# 0               6   Sep  weekend
# 1               6   Sep  weekend
# ...

# %%
import pandas as pd
import plotly.express as px

# Assuming you have the 'green' DataFrame loaded with the dataset

fig = px.histogram(green, x='leasing_rate', nbins=20, histnorm='percent', title='Distribution of Leasing Rates in Green Buildings')
fig.update_layout(xaxis_title='Leasing Rate', yaxis_title='Frequency (%)')
fig.show()
# Out:
# <div>                            <div id="8d57a969-a4bc-497a-a259-2839b270bf58" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d57a969-a4bc-497a-a259-2839b270bf58")) {                    Plotly.newPlot(                        "8d57a969-a4bc-497a-a259-2839b270bf58",                        [{"alignmentgroup":"True","bingroup":"x","histnorm":"percent","hovertemplate":"leasing_rate=%{x}\u003cbr\u003epercent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":20,"offsetgroup":"","orientation":"v","showlegend":false,"x":[91.39,87.14,88.94,97.04,96.58,92.74,94.33,91.02,99.32,93.54,83.61,95.69,100.0,95.62,67.48,85.41,97.06,63.87,79.65,0.0,95.59,86.95,100.0,41.66,86.08,92.04,
# ...

# %%
px.box(green,x='leasing_rate')
# Out:
# <div>                            <div id="9365d05a-7a07-4efc-9035-5a6e9ebb120d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9365d05a-7a07-4efc-9035-5a6e9ebb120d")) {                    Plotly.newPlot(                        "9365d05a-7a07-4efc-9035-5a6e9ebb120d",                        [{"alignmentgroup":"True","hovertemplate":"leasing_rate=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[91.39,87.14,88.94,97.04,96.58,92.74,94.33,91.02,99.32,93.54,83.61,95.69,100.0,95.62,67.48,85.41,97.06,63.87,79.65,0.0,95.59,86.95,100.0,41.66,86.08,92.04,98.31,97.36,96.75,71.1,100.0,89.26,85.19,73.64,95.54,79.79,99.46,83.33,93.08,94.3
# ...

# %% [markdown]
# From the above two charts, we can clearly that
